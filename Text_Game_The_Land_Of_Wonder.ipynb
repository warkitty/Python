# %%
"""
Made by: Anne Melaas
For Data Science: Python – Hult 
October 17th 2020
Time: -4 depending on the decision.


Docstring:
Story: The game is about a person in the world of Entios how is asked to deliver 
a letter to the wizard in Latos and have to cross a forest or a mountain to get there. 
The roads giving him tasks and depending on what the player does, they might die, 
get sent back or just run through the game.

Feedback: I have not identified any bugs, however. If the player keep taking the same option, 
they will be playing forever. Depending on the reading ability and on how many loops you 
will get the game will get longer. If the player takes the right choices all the way, 
will the game be around 2-3 min. So the biggest bug identified is the time.

"""

############################################################################################################
############################################################################################################

#instaling pacaging
import random
import time
import sys

#Adding color & teksture text
class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'
    
#Library of names, place and shortkey
country_name = "Morgana"
universe_name = "Entios"
wizard_place = "Latos"
global user_name
TLOW = "The Land Of Wonder"

#Loops to reask the question and restart the game
game_flag = 1
toContinue = 0

def checkExitGame():

    while 1:
        isExit = input("Are you sure you want to exit the game? (Yes/No)")
            
        if isExit.lower() == "yes" or isExit.lower() == "y" or isExit.lower() == "exit":
            print("Okay! Maybe an other time")
            return 1
            
        #If user types no, they will be sent back     
        elif isExit.lower() == "no" or isExit.lower() == "n":
            print("Let's try again.")
            return 0
            
        #If user try to write something else, they will be asked the question again
        else:
            print("Something went wrong! Answer with Yes or No")


def introStage():
      
    intro_flag = 1
    while intro_flag:
        
    #Ask if player is ready to become a hero using their username {user_name} and country_name. 
    #Use the input statment and ask for yes or no. Make sure to alow user to user y and n as well to answer. 
        answer = input(f"""
Are you {user_name} ready to be {country_name}s new Hero? (Yes/No)
        """) 
        answer = answer.casefold()

        if answer.lower() == "y" or answer.lower() == "yes":
            print("Awesome, lets get started!")
            intro_flag = 0
            time.sleep(2)
        #If the user says no, the user they will have the option again to make sure of their action 

        elif answer.lower() == "n" or answer.lower() == "no":
            intro_flag = 0
            isExit = checkExitGame()
            if isExit:
                return 0
            else:
                return 2
        
        else:
            print ("Please answer either yes or no.")

def roadStage():
    choice = 0
    road_flag = 1
    while road_flag:
        
            #Give the user the option to go in the forest or up the mountain
        road = input(f"""    
What will you do, {user_name}? (1/2)
    1. Walk into the dark mysterious forest
    2. Start to walk up the high mountain road
                    """)

        road = road.lower()
    
        #Use the if statement with options to enter forest

        if road == "1" or road == "forest" or road == "one" or road == "into" or road == "myterious":
            print("""
You are walking into the forest... there almost impossible to see.
You starting to hear a voice from a distance. You see an old woman wearing only old and used clothing.
She's talking to herself and minded her own business until she sees you!""")
            time.sleep(3)
            
            print("""
        Old woman: 
                I was a farmer in was in my younger days, well, or I think I was... 
                I might have been a monk! But I don't remember that either.. it has been years since I 
                staring to forget, that I do remember... I had a pet! I can't seem to find it though... 
                """)
            choice = 1
            road_flag = 0
            empty = input('Press Enter to continue the story...')

        #Use elif statment if the user takes the road into the mountain

        elif road == "2" or road == "mountain" or road == "two" or road == "up" or road == "road" or road == "high":
            print(f"""You trying to walk up the mountain. The view is extraordinary and you can see enchanted 
dark forest rambling underneath you while you climbing up.

You soon to understand it's starting to be too steep to walk.
                        """)
            choice = 2
            road_flag = 0
            
    #If user try to wright something else, they will be asked the question again
        else:
            print("Something went wrong! Answer with 1 or 2")
        
    time.sleep(2)
    road_flag = 1
            
    #Make new loops, depending on the answer, the user needs to go back.           
    if choice == 1:
            while road_flag:
                second_choice = input(f"""
What will you do, {user_name}? 
    1. Ask the old woman for directions to {wizard_place}!
    2. Listen to what the old woman is trying to say
    3. Continue your path 
                                    """)
                                    
                second_choice = second_choice.lower()
                    
            #If user asks the woman, they wil loos their wan and will be sent back to where the roads are splitting                    
                if second_choice == "1" or second_choice == "ask" or second_choice == "one" or second_choice == "listen woman" or second_choice == "direction" or second_choice == "Ask the old woman for directions" or second_choice == "wizard" or second_choice == wizard_place:
                    print("""
You are trying to talk to the old lady, asking for directions.
But it seems like she won't listen to what you are trying to say. 
                            """)
                    print("* "*30)
                    print("""
Let`s see if she does!
Roll the dice and guess the right number, you can try up to 3 times!
                            """)
                    # declaring objects, random number remains the same for each guess
                    number = random.randint(1,10) 
                    chances = 3 

                    #Test to see if guess work
                    #print("number: " + str(number))


                    # looping until a user is out of guesses
                    while chances > 0:
                        choice = input("What is your guess (1-10)? You have three chances to guess.")

                        # converting choice for numerical comparison
                        # conditional statement based on user input
                        # 1) if the user input is number and matches randomly generated number, they move on.

                        if choice == str(number):
                            print("That's correct!")
                            lost_flag = 0
                            return lost_flag

                        # 2) if the user input is number and doesn't match

                        elif choice != str(number):

                            chances = chances - 1
                            print(f"""
Oh, no that's incorrect! You have {chances} tries left!
""")

                        # setting a different error message for inner and outer loops
                        else:
                            print("Please type a number.")
                            print("* "* 30)
            
                    # If the user used up all three chances for guessing, the user will fall down and die.
                    if chances == 0:
                    
                        print(""" 
Seems like she just contineus talkin and didnt pay atention to you. You decide to 
contineu walking in the dark forest.However, you can't find the exit after entering. 
There is no road anymore.

You see a light and walk toward it, it seems to be a flower. A white flower as bright as the moon.
You starting to feel dizzy and passing out. """)
                        time.sleep(7)
                        
                        print(color.BOLD + color.RED + "It seems like there was a poison in the flower and by just smelling it is fatal." + color.END)
                        time.sleep(2)

                        print("""
Oh no! You are dead...
""")
                        time.sleep(2)
                        road_flag = 0

                        #If the caracter die, ask if want to play again, if yes, restart the game, if no exit the game                    
                        isExit = checkExitGame()
                
                        if isExit:
                            lost_flag = 2
                        else:
                            lost_flag = 3
                        
                        return lost_flag
                            
                
                #Elif the user choose to lisen to the woman, the user will be able to know the road and contineu. 
                elif second_choice == "2" or second_choice == "listen" or second_choice == "two"  or second_choice == "idk":
                    print(""" 
You decided to try to listen to the confused old lady. 
Nothing made sense, really. She was just saying random things, but you stayed put.

After a couple of minutes, she turns to you quietly.
""")
                    
                    #Use an empty input command to make a flow
                    empty = input('Press Enter to continue the story...')
                    print(f"""
    Old Woman:
            You actually listen to me! Thank you!
            I assume you want to enter {wizard_place}! Head north and take a left when you see the stonehill. 
                            """)

                    road_flag = 0

            #If the user desides to keep waling, they will aso end up in the road splitt
                elif second_choice == "3" or second_choice == "continue" or second_choice == "three" or second_choice == "leave"or second_choice == "path":
                    print("""
You continue your path deeper into the dark forest.

But oh no!

it seems like you got lost and are back where the roads are splitting!!
""")
                    time.sleep(5)

                    road_flag = 0
                    lost_flag = 1
                    return lost_flag
                    
                #If the anwer is not valid, ask them again. by the use of else:
                else:
                    print("Something went wrong! Answer with 1,2 or 3")
    #If user gos toward the mountain, give two option, climb or fina away. This is a new area and needs to spesefied in the loop.
    elif choice == 2:
            while road_flag:
                second_choice = input(f"""
What will you do, {user_name}?
     1. Start to climb the mountain! 
     2. Find a way around 
                            """)
                    
            #If user takes the option one, they will need to guess the right number max 3 times or they die.                  
                if second_choice == "1" or second_choice == "climb" or second_choice == "one" or second_choice == "Mountain" or second_choice == "up":
                    print("* "*30)
                    print("""
Lets see if you can!
Roll the dice and guess the right number, you can try up to 3 times!
                            """)
                    # declaring objects, random number remains the same for each guess
                    number = random.randint(1,10) 
                    chances = 3 

                    print("number: " + str(number))
                    # looping until a user is out of guesses
                    while chances > 0:
                        choice = input("What is your guess (1-10)? You have three chances to guess.")

                        # converting choice for numerical comparison
                        # conditional statement based on user input
                        # 1) if the user input is number and matches randomly generated number, they move on.

                        if choice == str(number):
                            print("That's correct!")
                            lost_flag = 0
                            return lost_flag

                        # 2) if the user input is number and doesn't match

                        elif choice != str(number):

                            chances = chances - 1
                            print(f"""Oh, no that's incorrect! You have {chances} tries left!
                            """)
                            print("* "* 30)

                        # setting a different error message for inner and outer loops
                        else:
                            print("Please type a number.")
                            print("* "* 30)
            
                    # If the user used up all three chances for guessing, the user will fall down and die.
                    if chances == 0:
                        
                        print("""
You staring to get a grip on the stones and climes up,
however, it's too steep!
You're foot slips, making you fall down. 
While falling you know there is no hope. 
There is nothing under you beside a bunch of rocks.
""")
                        time.sleep(5)
                
                        #To make the use know they died, use bold red color to higligt.
                        print(color.BOLD + color.RED + """
A rock hits you're head, and your bleeding badly.
You die of the injury.""" + color.END)

                        # Check if the user wants to exit the game. Otherwise, restart the game.
                        isExit = checkExitGame()
                    
                        if isExit:
                            lost_flag = 2
                        else:
                            lost_flag = 3
                        
                        return lost_flag

                    

            #If user tries to go around they will die, ask the user if want to play one more time.
                elif second_choice == "2" or second_choice == "find" or second_choice == "two" or second_choice == "around" or second_choice == "down":
                    print("* "* 30)
                    print("""
There is no hope, you are trying to walk around the mountain instead of climbing up, 
but you don't know longer where you are!
                           """)
                    time.sleep(5)
                    print("Wait, oh no! You are back where the roads are splitting again!")

                                  
                    lost_flag = 1
                    return lost_flag

                else:
                    print("Please choose 1 or 2.")
            
       
            time.sleep(2)
            return lost_flag

#Start the game, use game_flag so the player has something to return too. 
while game_flag:
    game_flag = 1
    # Show Frontpage, make the name of the story in bold and in red color to grab Attention   
    print("* "*30)
    print("Welcome adventurer to the chapter of " + color.BOLD + color.RED + TLOW + color.END)
    print("* "*30)
    print("")
    
    ## Use the sleep function to make some tension and flow in the adventure. Use time.sleep() add the second. 
    time.sleep(2)
    
    #Ask after username to personalize the character. use the print statment to ask and use input()to get reply 
    print('')
    user_name = input("What will your username be? ")
    user_name = user_name.capitalize()

    #Welcome player using {user_name}
    time.sleep(1)
    print(f"""
    Welcome to the game {user_name}! 
    """)
    
    ## Use the sleep function to make some tension and flow in the adventure. Use time.sleep() add the second. 
    time.sleep(2)
    
    # Make a backgound story of the world as a intro to the game so the player know what the game is about. 
    #Use use the {} on names than can be changed and used several times. Put them in libary.

    print(f"""
    You are now in the universe of {universe_name} where you are our main character! 
    Congrats! {universe_name} is a huge universe where you can find the strangest things, 
    so be prepared for anything. 
    """)

    print("* "*30)

    ## Use the sleep function to make some tension and flow in the adventure. Use time.sleep() add the second. 
    time.sleep(7)  

    # run intro
    game_flag = introStage()


    
    # If game_flag = 0, the user wants to stop playing so we get out of most outer loop and let the program end. Otherwise, restart the game.
    if game_flag == 0:
        break
    elif game_flag == 2:
        continue

    #Use the sleep function to make som tention and flow in the adventure. Use time.sleep() add the second.
    time.sleep(2)

    
    #Strat the story Cp1. {country.name}. Starting with print() tell what is going on.        
    print("* "* 30)
    print(f"""
You just arrived {country_name}. You head into the brown bar, the only place it looks like there is someone...
You can feel the atmosphere is heavy. The people are looking at you like they never have seen someone like 
you before.
""")
        
    #Use the sleep function to make som tention and flow in the adventure. Use time.sleep() add the second.
    time.sleep(5) 

    #print() intro to bar to make a story toward the bartender    
    print("""As you sit down in front of the counter the bartender approach to you, like he's been waiting for you to come!""")
    
    #Use an empty input command to make a flow
    empty = input('Press Enter to continue the story...')
    time.sleep(3)
    ##Give the user a quest and a meaning to play
    print(f"""
            Bartender: 
                You must be {user_name}! 
                I heard so much about you! I need you to go into the deliver this letter to the wizard in {wizard_place}
                as fast as you can! Here is the letter!
            """)
    print("* "* 30)
    empty = input('Press Enter to continue the story...')
                
    print("""
As you heading in the direction the bartender has given, is there a road going in two directions.
One is going toward a dark mysterious forest and the other one looks like a mountain road-going pretty high.
""")
    
    #Use the sleep function to make som tention and flow in the adventure. Use time.sleep() add the second.
    time.sleep(2)
    
    #New input stament with chooises needs new loops. Depending on optinn they will be sent to a new place
    road_flag = 1
    choice = 0
    
    lost_flag = 1
    
    #Creat a loop for the user so they can return to road
    while lost_flag:
        lost_flag = 0
        lost_flag = roadStage()

        if lost_flag == 2:
            game_flag = 2
            lost_flag = 0

        elif lost_flag == 3:
            game_flag = 3
            lost_flag = 0
    
    if game_flag == 2:
        break
    elif game_flag == 3:
        continue
             

    #If the user survive they have now a new place 
    print("You are starting to see something that looks like a " + color.RED + "cave" + color.END)
    time.sleep(3)
    print("""
You starting to hear a strange sound, like never heard before. 
It has to come from the inside of the cave! Maybe all the disappearing is happening in here?""")

    #Crate the last area, the cave. New place, new flag.
    cave_flag = 1
    while cave_flag:

        #Insert input to ask the player for a desition if go in cave or elif back.
        cave = input(f"""
What will you do, {user_name}? (1/2)
    1. Go into the cave
    2. Go back 
    """)

        cave = cave.lower()

        #If the user goes into the cave, they winn the game! use the if statmen and print an ending
        if cave == "1" or cave == "cave" or cave == "in" or cave == "go" or cave == "into" or cave == "one":
            print(f"""
You are heading into the cave. It's dark, but you keep walking.
You starting to see the light shining in the end to the cave.
""")
        
            #Use input '' to build tention 
            empty = input("""Press Enter to continue the story...
            """)
            print(f"As you head out you can see the {wizard_place} and the wizards building!")
            time.sleep(3)
            #Use visuals the make the user see whats happening    
            print("""
                                               /\      /\
                                               ||______||
                                               || ^  ^ ||
                                               \| |  | |/
                                                |______|
              __                                |  __  |
             /  \       ________________________|_/  \_|__
            / ^^ \     /=========================/ ^^ \===|
           /  []  \   /=========================/  []  \==|
          /________\ /=========================/________\=|
       *  |        |/==========================|        |=|
      *** | ^^  ^^ |---------------------------| ^^  ^^ |--
     *****| []  [] |           _____           | []  [] | |
    *******        |          /_____\          |      * | |
   *********^^  ^^ |  ^^  ^^  |  |  |  ^^  ^^  |     ***| |
  ***********]  [] |  []  []  |  |  |  []  []  | ===***** |
 *************     |         @|__|__|@         |/ |*******|
***************   ***********--=====--**********| *********
***************___*********** |=====| **********|***********
 *************     ********* /=======\ ******** | *********""")
            time.sleep(5)
            
            print( "* " * 30)
            print(color.GREEN + f"You did it! You survived the path! You were able to delive the letter, well done {user_name}!" + color.END)
            print( color.GREEN + color.BOLD + "You won! Congrats!!" + color.END)

            cave_flag = 0
            game_flag = 0
            
        #Make a last death option
        elif cave == "2" in cave or "back" in cave or "home" in cave or "two" in cave or "no" in cave:
            print("* "* 30)
            print("""
You decide this is not the right way and try to walk back, you enter the dark forest.
However, you can't find the exit after entering. There is no road anymore.

You see a light and walk toward it, it seems to be a flower. A white flower as bright as the moon.
You starting to feel dizzy and passing out.
""")
            time.sleep(7)
            
            print(color.BOLD + color.RED + "It seems like there was a poison in the flower and by just smelling it is fatal." + color.END)
            time.sleep(2)

            print("""
Oh no! You are dead...
""")
            time.sleep(2)
            cave_flag = 0

            #If the caracter die, ask if want to play again, if yes, restart the game, if no exit the game                    
            isExit = checkExitGame()
            if isExit:
                game_flag = 0
            else:
                game_flag = 2
